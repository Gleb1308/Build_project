# %% [markdown]
# # Install project

# %%
# !git clone https://github.com/Gleb1308/Build_project.git
# Out:
# Cloning into 'Build_project'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 66 (delta 25), reused 4 (delta 0), pack-reused 0
# Receiving objects: 100% (66/66), 43.24 KiB | 8.65 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# !pip install -r Build_project/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %% [markdown]
# # Install dataset

# %%
import zipfile

# %%
# !mkdir ~/.kaggle

# %%
# !echo '{"username":"kaggle_username","key":"kaggle_key"}' > ~/.kaggle/kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d glebsukhomlyn/kitti-dataset -p ./
# Out:
# Dataset URL: https://www.kaggle.com/datasets/glebsukhomlyn/kitti-dataset
# License(s): Apache 2.0
# ...
# 100% 5.68G/5.69G [04:32<00:00, 22.3MB/s]
# 100% 5.69G/5.69G [04:32<00:00, 22.4MB/s]

# %%
zip_ref = zipfile.ZipFile("./kitti-dataset.zip", 'r')
zip_ref.extractall("./kitti")
zip_ref.close()

# %% [markdown]
# # Install weights

# %%
import gdown
file_id = '1U7bRLXEgh4Am4qIQ0uQgfi4koRGvK8NN'
gdown.download(f"https://drive.google.com/uc?id={file_id}", 'weights.zip')
zip_ref = zipfile.ZipFile('/content/weights.zip', 'r')
zip_ref.extractall("/content/weights")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1U7bRLXEgh4Am4qIQ0uQgfi4koRGvK8NN
# From (redirected): https://drive.google.com/uc?id=1U7bRLXEgh4Am4qIQ0uQgfi4koRGvK8NN&confirm=t&uuid=973a354c-3915-41f9-aecd-97e774eb7b9b
# To: /content/weights.zip
# 100%|██████████| 1.10G/1.10G [00:13<00:00, 78.9MB/s]

# %% [markdown]
# # Inference

# %%
import os

# %%
# one image
# !python Build_project/infer.py --use_opt_params --to_save --model_path /content/weights/best_yolov8m.pt \
--source 000104.png
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VxZWLpMaKtpbJN11fHqjXCL3tLd5Ru5U
# To: /content/opt_params.csv
# 100% 335/335 [00:00<00:00, 1.77MB/s]
#
# image 1/1 /content/kitti/images/test/000104.png: 224x640 5 Cars, 158.3ms
# Speed: 11.4ms preprocess, 158.3ms inference, 730.8ms postprocess per image at shape (1, 3, 224, 640)
# Results saved to runs/detect/predict

# %%
# list of the images
ims = ','.join(os.listdir('/content/kitti/images/test/')[467:500])
# !python Build_project/infer.py --use_opt_params --to_save --model_path /content/weights/best_yolov8m.pt \
--source $ims --comma_sep
# Out:
# 0: 640x640 3 Cars, 1 Truck, 10.6ms
# 1: 640x640 3 Cars, 1 Pedestrian, 10.6ms
# 2: 640x640 3 Pedestrians, 1 Van, 10.6ms
# 3: 640x640 6 Cars, 1 Van, 10.6ms
# 4: 640x640 7 Cars, 1 Misc, 10.6ms
# 5: 640x640 2 Cars, 1 Cyclist, 1 Truck, 1 Van, 10.6ms
# 6: 640x640 7 Cars, 1 Truck, 10.6ms
# 7: 640x640 2 Cars, 1 Cyclist, 1 Van, 10.6ms
# 8: 640x640 1 Car, 10.6ms
# 9: 640x640 5 Cars, 2 Miscs, 1 Van, 10.6ms
# 10: 640x640 4 Cars, 10.6ms
# 11: 640x640 2 Cars, 1 Van, 10.6ms
# 12: 640x640 3 Cars, 1 Cyclist, 1 Van, 10.6ms
# 13: 640x640 1 Car, 1 Misc, 1 Pedestrian, 10.6ms
# 14: 640x640 4 Cars, 7 Pedestrians, 10.6ms
# 15: 640x640 1 Car, 10.6ms
# 16: 640x640 4 Cars, 10.6ms
# 17: 640x640 5 Cars, 1 Cyclist, 10.6ms
# 18: 640x640 3 Cars, 2 Miscs, 10.6ms
# 19: 640x640 2 Cars, 10.6ms
# 20: 640x640 3 Cars, 10.6ms
# 21: 640x640 4 Cars, 3 Cyclists, 10.6ms
# 22: 640x640 6 Cars, 1 Van, 10.6ms
# 23: 640x640 7 Cars, 1 Van, 10.6ms
# 24: 640x640 1 Car, 10.6ms
# 25: 640x640 1 Pedestrian, 10.6ms
# ...

# %%
# video file
# !python Build_project/infer.py --use_opt_params --to_save --model_path /content/weights/best_yolov8m.pt \
--source Cars_in_Highway_Traffic_FREE-STOCK_VIDEO.mp4 --source_path /content/
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1800) /content/Cars_in_Highway_Traffic_FREE-STOCK_VIDEO.mp4: 384x640 13 Cars, 1 Van, 150.8ms
# video 1/1 (frame 2/1800) /content/Cars_in_Highway_Traffic_FREE-STOCK_VIDEO.mp4: 384x640 12 Cars, 1 Van, 11.6ms
# video 1/1 (frame 3/1800) /content/Cars_in_Highway_Traffic_FREE-STOCK_VIDEO.mp4: 384x640 12 Cars, 1 Van, 9.4ms
# ...

# %% [markdown]
# # Training

# %%
# !python Build_project/train.py --epochs 77 --model_path /content/weights/best_yolov8m.pt
# Out:
# Ultralytics YOLOv8.2.71 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...
